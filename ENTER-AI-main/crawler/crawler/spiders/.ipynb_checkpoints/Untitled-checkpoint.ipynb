# %%
import pandas as pd

a = pd.read_csv('google_reviews.csv')

a.head()
# Out:
#                                                  url         site  \
# 0  https://play.google.com/store/search?q=지니뮤직&c=...  google_play
# 1  https://play.google.com/store/search?q=지니뮤직&c=...  google_play
# 2  https://play.google.com/store/search?q=지니뮤직&c=...  google_play
# 3  https://play.google.com/store/search?q=지니뮤직&c=...  google_play
# 4  https://play.google.com/store/search?q=지니뮤직&c=...  google_play
#
#                                             document  documenttype  \
# 0  상태창에서 반응 속도가 너무 느려요. 넘기기 눌러도 반응 없다가 앱 들어가면 갑자기...           NaN
# 1  이번에 요금제를 변경하면서 추가로 제공되길래 한번 사용해봤습니다. 허나 기존 스트리...           NaN
# 2  선택곡 반복 재생 다시 만들어주세요... 왜 없어졌나요.. 지금은 듣고 싶은 곡만 ...           NaN
# 3  플레이리스트에 새 곡 추가할 때 위로 쌓을건지 아래로 쌓을건지가 당연히 선택사항이어...           NaN
# 4  차량에서 무선으로 안드로이드 오토를 잘 사용하고 있었는데 무슨 EQ설정이 나와서 그...           NaN
#
#               postdate  likes  dislike  comment_cnt  views  boardcategory  \
# 0  2023-12-25 00:32:14     10      NaN          NaN    NaN            NaN
# ...

# %%
b = pd.read_csv('quesarzone_reviews.csv')

b.head()
# Out:
#                                                  url        site  \
# 0  https://quasarzone.com/groupSearches?keyword=지니뮤직  quesarzone
# 1  https://quasarzone.com/groupSearches?keyword=지니뮤직  quesarzone
# 2  https://quasarzone.com/groupSearches?keyword=지니뮤직  quesarzone
# 3  https://quasarzone.com/groupSearches?keyword=지니뮤직  quesarzone
# 4  https://quasarzone.com/groupSearches?keyword=지니뮤직  quesarzone
#
#                                             document  documenttype  \
# 0  지니뮤직 음악감상 100회 이용권 드립니다.\n조건은 없어요. \n유효기간은 26일...           NaN
# 1  지니뮤직 50회 스트리밍 쿠폰입니다!!\n퀘이사존 쪽지 기능을 이용해 보내드릴 예정...           NaN
# 2                                 자세한 내용은 링크를 참조하세요.           NaN
# 3  지니뮤직 앱에서만 감상 가능 합니다.기존에 사용하고 있으면 기간 연장이 아닌 +30...           NaN
# 4  Kt m 모바일 사용하면서 받은 지니뮤직 스마트 음악감상 3개월 이용권입니다.저는 ...           NaN
#
#            postdate  likes  dislike  comment_cnt  views  boardcategory  \
# 0  2019.03.20 11:46    NaN      NaN           53    897            NaN
# ...
